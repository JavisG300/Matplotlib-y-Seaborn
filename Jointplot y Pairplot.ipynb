# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(data=tips, x='total_bill',y='tip');

# %% [markdown]
# Junta un diagrama de dispersión y distribución.
# Aunque dependiendo de los datos seaborn te entrega los gráficos que cree pertinentes

# %%
sns.jointplot(data=tips, x='total_bill',y='tip', hue='sex');

# %%
sns.jointplot(data=tips, x='total_bill',y='tip', hue='sex',kind='hist');

# %%
sns.jointplot(data=tips, x='total_bill',y='tip', hue='sex',kind='kde');

# %%
sns.jointplot(data=tips, x='total_bill',y='tip', hue='sex',kind='hist',marginal_ticks=True);

# %%
sns.jointplot(data=tips, x='total_bill',y='tip', hue='sex',kind='hist',
marginal_ticks=True,marginal_kws=dict(bins=25)); #Los bins de marginal solo afectan a la sección marginal

# %%
sns.jointplot(data=tips, x='total_bill',y='tip', hue='sex',kind='hist',
marginal_ticks=True,marginal_kws=dict(bins=25,fill=False,multiple='dodge'));

# %% [markdown]
# ## Pairplot
#
# Esta funciona para todas las variables numéricas

# %%
sns.pairplot(data=tips);

# %%
sns.pairplot(data=tips,hue='sex',palette='coolwarm',corner=True); #Corner evita información duplicada
